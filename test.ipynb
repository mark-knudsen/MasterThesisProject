# %%
x= [1,2,3,4]

# %%
z = x

# %%
z
# Out:
# [1, 2, 3, 4]

# %%
x[0] = 4
x
# Out:
# [4, 2, 3, 4]

# %%
z
# Out:
# [4, 2, 3, 4]

# %%
c = z.copy()

# %%
import pandas as pd
import numpy as np


np.seri
